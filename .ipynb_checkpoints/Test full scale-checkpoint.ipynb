# %% [markdown]
# ## Import

# %%
#gestion fichier
import os , sys            
workpath = sys.path[0]
bddpath  = workpath + r'\BDDfactory'

sys.path.append(f'{workpath}\\fidle-notebook')
sys.path.append(f'{workpath}\\BDDfactory\\lib')

#modules utilitaires
import random as r
import numpy as np
import time
import fidle.pwk as pwk
from distrib import *
             
#traitement image
import matplotlib.pyplot as plt   
from skimage import io 

#module IA
import tensorflow as tf       
from tensorflow import keras
from tensorflow.keras.callbacks import TensorBoard

# %% [markdown]
# ## Config training

# %%
#Choix dataset + échelle
data = r'\BDD(256)(equalized)(real-noise)'
scale = 0.3

#Config thread optimal
if tf.config.threading.get_inter_op_parallelism_threads() != 0 or tf.config.threading.get_intra_op_parallelism_threads() != 0:
    tf.config.threading.set_inter_op_parallelism_threads(0)
    print ( tf.config.threading.get_inter_op_parallelism_threads()   )
    tf.config.threading.set_intra_op_parallelism_threads(0)
    print ( tf.config.threading.get_intra_op_parallelism_threads()   )

index_to_class = ["CUBO","DEC","FCC","FCC-sphere","HCP-sphere","ICO","MnBeta_sphere","OH","RTD","BCC","DODECA"]

# %% [markdown]
# ## BDD loading

# %%
def read_dataset (filepath : str):
    """entrée : chemin vers le dossier contenant la BDD
    sortie : listes des images et leur classes respectives, mis à l'echelle et mélangé"""
    
    L = os.listdir(filepath)   #liste contenenant le nom (en .jpg) de toutes les images
    nb_files = len(L)
    nb_files2load = round(nb_files*scale)
    size = np.shape(io.imread(f'{filepath}\{L[0]}' , as_gray = True))
    
    #initialisation listes sortie
    img = np.zeros ( (nb_files2load , size[0] , size[1]) , dtype = np.float16 )
    ID  = np.zeros ( nb_files2load , dtype = np.int8)
   
    for i in range (nb_files2load):
        
        random_index = r.randint(0 , nb_files - i - 1)
        img[i] = io.imread (f'{filepath}\{L[random_index]}',as_gray = True)
        ID [i] = int (L[random_index][:3]) - 1
        L.pop(random_index)
        
    N = len(img)
    img_train = img[0:round(N*0.8)]
    img_test  = img[round(N*0.8):]
    ID_train  = ID [0:round(N*0.8)]
    ID_test   = ID [round(N*0.8):]    
    
    return img_train,img_test,ID_train,ID_test


img_train , img_test , ID_train , ID_test = read_dataset(bddpath + data)
print (np.shape(img_train))
print (np.shape(img_test))
print (np.shape(ID_train))
print (np.shape(ID_test))
distrib_BDD (bddpath + data)
# Out:
# (4810, 256, 256)
# (1202, 256, 256)
# (4810,)
# (1202,)
# Part of CUBO in BDD = 9.156686626746508 %
#
# Part of DEC in BDD = 9.141716566866268 %
#
# Part of FCC in BDD = 9.006986027944112 %
#
# Part of FCC-sphere in BDD = 8.987025948103792 %
#
# Part of HCP-sphere in BDD = 9.181636726546905 %
#
# Part of ICO in BDD = 9.02694610778443 %
#
# Part of MnBeta-sphere in BDD = 9.04191616766467 %
#
# Part of OH in BDD = 9.061876247504989 %
#
# Part of RTD in BDD = 9.251497005988025 %
#
# Part of BCC in BDD = 9.126746506986027 %
#
# Part of DODECA in BDD = 9.01696606786427 %

# %% [markdown]
# ## Modèles

# %%
def create_model_1(lx,ly):
    model = keras.models.Sequential()
    
    model.add( keras.layers.Conv2D(32, (3,3),  activation='relu', input_shape=(lx,ly,1)))
    model.add( keras.layers.MaxPooling2D((3, 3)))
    #model.add( keras.layers.Dropout(0.1))

    model.add( keras.layers.Conv2D(64, (3, 3), activation='relu'))
    model.add( keras.layers.MaxPooling2D((2, 2)))
    #model.add( keras.layers.Dropout(0.1))

    model.add( keras.layers.Conv2D(128, (3, 3), activation='relu'))
    model.add( keras.layers.MaxPooling2D((2, 2)))
    #model.add( keras.layers.Dropout(0.1))

    model.add( keras.layers.Conv2D(256, (3, 3), activation='relu'))
    model.add( keras.layers.MaxPooling2D((2, 2)))
    #model.add( keras.layers.Dropout(0.1))

    model.add( keras.layers.Flatten()) 
    model.add( keras.layers.Dense(1000, activation='relu'))
    #model.add( keras.layers.Dropout(0.1))

    model.add( keras.layers.Dense(11, activation='softmax'))
    return model

def create_model_2(lx,ly):
    model = keras.models.Sequential()
    
    model.add( keras.layers.Conv2D(64, (3,3),  activation='relu', input_shape=(lx,ly,1)))
    model.add( keras.layers.MaxPooling2D((2, 2)))
    
    model.add( keras.layers.Conv2D(64, (3, 3), activation='relu') )
    model.add( keras.layers.MaxPooling2D((2, 2)))
    
    model.add( keras.layers.Conv2D(64, (3, 3), activation='relu') )
    model.add( keras.layers.MaxPooling2D((2, 2)))
    
    model.add( keras.layers.Conv2D(64, (3, 3), activation='relu') )
    model.add( keras.layers.MaxPooling2D((2,2)))
    
    model.add( keras.layers.Flatten() )
    model.add( keras.layers.Dense(1000, activation='relu') )
    model.add( keras.layers.Dense(11, activation='softmax') )
    
    return model

def create_model_3 (lx,ly):
    model = keras.models.Sequential()
    
    model.add( keras.layers.Conv2D(1, (3 ,3),  activation='relu', input_shape=(lx,ly,1)))
    model.add( keras.layers.MaxPooling2D((2, 2)))
    
    model.add( keras.layers.Conv2D(1, (3, 3), activation='relu') )
    model.add( keras.layers.MaxPooling2D((2, 2)))
    
    model.add( keras.layers.Conv2D(1, (3, 3), activation='relu') )
    model.add( keras.layers.MaxPooling2D((2, 2)))
    
    model.add( keras.layers.Conv2D(1, (3, 3), activation='relu') )
    model.add( keras.layers.MaxPooling2D((2,2)))
    
    model.add( keras.layers.Flatten() )
    model.add( keras.layers.Dense(1000, activation='relu') )
    model.add( keras.layers.Dense(11, activation='softmax') )
    
    return model

# %% [markdown]
# ## Compile and Train

# %%
(nb_img,lx,ly) = np.shape(img_train)

''' CHOOSE YOUR MODEL !!!!!!! '''
model = create_model_2(lx,ly)

model.summary()

model.compile(optimizer = 'adam',
              loss      = 'sparse_categorical_crossentropy',
              metrics   = ['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 84, 84, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 82, 82, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 41, 41, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 39, 39, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 19, 19, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 17, 17, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 1000)              16385000
#
#  dense_1 (Dense)             (None, 11)                11011
#
# ...
# Total params: 16,783,851
# Trainable params: 16,783,851
# Non-trainable params: 0
# ...

# %%
# ---- Hyperparamètres

batch_size    = 128
epochs        = 20
fit_verbosity = 1

# ---- Save when improvement 

date = '09.02.23'

save_dir = f'{workpath}\\mod\\trained_model\model.h5'
bestmodel_callback = tf.keras.callbacks.ModelCheckpoint(filepath=save_dir, verbose=0, monitor='accuracy', save_best_only=True)

# ---- Shuffle train data

img_train , ID_train = pwk.shuffle_np_dataset(img_train , ID_train)


# ---- Train
t1 = time.time()

history = model.fit(  img_train, ID_train,
                      batch_size      = batch_size,
                      epochs          = epochs,
                      verbose         = fit_verbosity,
                      validation_data = (img_test,ID_test ),
                      callbacks = [bestmodel_callback] )
                   

t2 = time.time()
print(f'Entrainement en {int((t2-t1)//60)} minutes et {int((t2-t1)%60)} secondes')

pwk.plot_history(history)
max_val_accuracy = max(history.history["val_accuracy"])

print("Max validation accuracy is : {:.4f}".format(max_val_accuracy))
score = model.evaluate(img_test, ID_test, verbose=0)
print('Test loss      : {:5.4f}'.format(score[0]))
print('Test accuracy  : {:5.4f}'.format(score[1]))

model_name = data[1:] + '-(e' + str(epochs) + '-bs' + str(batch_size) + '-sc'+ str(scale) + '-mxacc=' + str(max_val_accuracy)[:5] + ')-' + date

if 'model.h5' in os.listdir(f'{workpath}\mod\\trained_model'):
    print('o')
    os.rename (f'{workpath}\\mod\\trained_model\\model.h5' , f'{workpath}\\mod\\trained_model\\{model_name}.h5')
# Out:
# Epoch 1/20
# 26/38 [===================>..........] - ETA: 38s - loss: 2.4441 - accuracy: 0.1692
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [47], line 22
#      19 # ---- Train
#      20 t1 = time.time()
# ---> 22 history = model.fit(  img_train, ID_train,
#      23                       batch_size      = batch_size,
#      24                       epochs          = epochs,
#      25                       verbose         = fit_verbosity,
#      26                       validation_data = (img_test,ID_test ),
#      27                       callbacks = [bestmodel_callback] )
#      30 t2 = time.time()
#      31 print(f'Entrainement en {int((t2-t1)//60)} minutes et {int((t2-t1)%60)} secondes')
#
# File c:\users\33648\desktop\pmd\fidle\fidle-env\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
# ...

# %%
y_sigmoid = model.predict(img_test)
y_pred    = np.argmax(y_sigmoid, axis=-1)

pwk.plot_confusion_matrix(ID_test,y_pred,range(11), figsize=(16, 16),normalize=False, save_as='04-confusion-matrix')
# Out:
# 38/38 [==============================] - 3s 76ms/step
